# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("uncleaned_vectors.csv")
# Out:
# C:\Users\santosh bishnoi\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (9,14,17,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  \
# 0           0             0    916600  01-01-2021    TX     33.0     33.0
# 1           1             1    916601  01-01-2021    CA     73.0     73.0
# 2           2             2    916602  01-01-2021    WA     23.0     23.0
# 3           3             3    916603  01-01-2021    WA     58.0     58.0
# 4           4             4    916604  01-01-2021    TX     47.0     47.0
#
#    CAGE_MO SEX RPT_DATE  ... BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 0      NaN   F      NaN  ...          NaN         Y         NaN
# 1      NaN   F      NaN  ...          NaN         Y         NaN
# 2      NaN   F      NaN  ...          NaN       NaN           Y
# 3      NaN   F      NaN  ...          NaN       NaN         NaN
# 4      NaN   F      NaN  ...          NaN       NaN         NaN
#
#                                            ALLERGIES  \
# 0                                  Pcn and bee venom
# 1                                            "Dairy"
# 2                                          Shellfish
# 3  Diclofenac, novacaine, lidocaine, pickles, tom...
# 4                                                NaN
#
#                                 other_meds_filtered  \
# 0                                               NaN
# 1  ['residing nursing facility . patients chart .']
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#                                   allergies_filtered  \
# 0                               ['pcn', 'bee venom']
# 1                                    ["`` dairy ''"]
# 2                                      ['shellfish']
# 3  ['diclofenac', 'novacaine', 'lidocaine', 'pick...
# 4                                                NaN
#
#                                     history_filtered  \
# 0                                                NaN
# 1   ['residing nursing facility . patients chart .']
# 2                                                NaN
# 3  ['diverticulitis', 'mitral valve prolapse', 'o...
# 4                                                NaN
#
#                                          meds_vector  \
# 0                                                NaN
# 1  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     allergies_vector  \
# 0  [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1  [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2  [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3  [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                NaN
#
#                                       history_vector
# 0                                                NaN
# 1  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 2                                                NaN
# 3  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 4                                                NaN
#
# [5 rows x 43 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'VAERS_ID', 'RECVDATE', 'STATE',
#        'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX', 'RPT_DATE', 'SYMPTOM_TEXT',
#        'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT', 'HOSPITAL', 'HOSPDAYS',
#        'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE', 'ONSET_DATE', 'NUMDAYS',
#        'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY', 'OTHER_MEDS', 'CUR_ILL', 'HISTORY',
#        'PRIOR_VAX', 'SPLTTYPE', 'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT',
#        'OFC_VISIT', 'ER_ED_VISIT', 'ALLERGIES', 'other_meds_filtered',
#        'allergies_filtered', 'history_filtered', 'meds_vector',
#        'allergies_vector', 'history_vector'],
#       dtype='object')

# %%
data.drop(['RECVDATE', 'STATE',
        'CAGE_YR', 'CAGE_MO', 'RPT_DATE', 'SYMPTOM_TEXT',
       'DATEDIED',  'HOSPDAYS',
       'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE', 'ONSET_DATE', 'NUMDAYS',
       'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY', 'OTHER_MEDS', 'CUR_ILL', 'HISTORY',
       'PRIOR_VAX', 'SPLTTYPE', 'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT',
       'OFC_VISIT', 'ER_ED_VISIT', 'ALLERGIES', 'other_meds_filtered',
       'allergies_filtered', 'history_filtered'],axis='columns', inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  VAERS_ID  AGE_YRS SEX DIED L_THREAT ER_VISIT  \
# 0           0             0    916600     33.0   F  NaN      NaN      NaN
# 1           1             1    916601     73.0   F  NaN      NaN      NaN
# 2           2             2    916602     23.0   F  NaN      NaN      NaN
# 3           3             3    916603     58.0   F  NaN      NaN      NaN
# 4           4             4    916604     47.0   F  NaN      NaN      NaN
#
#   HOSPITAL                                        meds_vector  \
# 0      NaN                                                NaN
# 1      NaN  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2      NaN                                                NaN
# 3      NaN                                                NaN
# 4      NaN                                                NaN
#
#                                     allergies_vector  \
# 0  [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1  [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2  [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3  [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                NaN
#
#                                       history_vector
# 0                                                NaN
# 1  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 2                                                NaN
# 3  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 4                                                NaN

# %%
data.drop(['Unnamed: 0','Unnamed: 0.1'],axis='columns', inplace=True)

# %%
data.head()
# Out:
#    VAERS_ID  AGE_YRS SEX DIED L_THREAT ER_VISIT HOSPITAL  \
# 0    916600     33.0   F  NaN      NaN      NaN      NaN
# 1    916601     73.0   F  NaN      NaN      NaN      NaN
# 2    916602     23.0   F  NaN      NaN      NaN      NaN
# 3    916603     58.0   F  NaN      NaN      NaN      NaN
# 4    916604     47.0   F  NaN      NaN      NaN      NaN
#
#                                          meds_vector  \
# 0                                                NaN
# 1  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     allergies_vector  \
# 0  [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1  [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2  [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3  [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                NaN
#
#                                       history_vector
# 0                                                NaN
# 1  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 2                                                NaN
# 3  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 4                                                NaN

# %%
data["DIED"]=data["DIED"].replace(np.nan, 0)
data["L_THREAT"]=data["L_THREAT"].replace(np.nan, 0)
data["ER_VISIT"]=data["ER_VISIT"].replace(np.nan, 0)
data["HOSPITAL"]=data["HOSPITAL"].replace(np.nan, 0)

# %%
data["DIED"]=data["DIED"].replace("Y", 1)
data["L_THREAT"]=data["L_THREAT"].replace("Y", 1)
data["ER_VISIT"]=data["ER_VISIT"].replace("Y", 1)
data["HOSPITAL"]=data["HOSPITAL"].replace("Y", 1)

# %%
data
# Out:
#         VAERS_ID  AGE_YRS SEX  DIED  L_THREAT  ER_VISIT  HOSPITAL  \
# 0         916600     33.0   F     0         0         0         0
# 1         916601     73.0   F     0         0         0         0
# 2         916602     23.0   F     0         0         0         0
# 3         916603     58.0   F     0         0         0         0
# 4         916604     47.0   F     0         0         0         0
# ...          ...      ...  ..   ...       ...       ...       ...
# 444314   1553408      NaN   M     0         0         0         0
# 444315   1553414      NaN   M     0         0         0         0
# 444316   1553416     81.0   F     0         0         0         0
# 444317   1553436     19.0   M     0         0         0         0
# 444318   1553448     64.0   M     0         0         0         1
#
#                                               meds_vector  \
# 0                                                     NaN
# 1       [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 444314  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 444315                                                NaN
# 444316  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 444317                                                NaN
# 444318                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 444314                                                NaN
# 444315                                                NaN
# 444316                                                NaN
# 444317  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444318                                                NaN
#
#                                            history_vector
# 0                                                     NaN
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 2                                                     NaN
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 4                                                     NaN
# ...                                                   ...
# 444314  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444315                                                NaN
# 444316  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444317                                                NaN
# 444318                                                NaN
#
# [444319 rows x 10 columns]

# %%
data = pd.get_dummies(data, columns=['SEX'])

# %%
data
# Out:
#         VAERS_ID  AGE_YRS  DIED  L_THREAT  ER_VISIT  HOSPITAL  \
# 0         916600     33.0     0         0         0         0
# 1         916601     73.0     0         0         0         0
# 2         916602     23.0     0         0         0         0
# 3         916603     58.0     0         0         0         0
# 4         916604     47.0     0         0         0         0
# ...          ...      ...   ...       ...       ...       ...
# 444314   1553408      NaN     0         0         0         0
# 444315   1553414      NaN     0         0         0         0
# 444316   1553416     81.0     0         0         0         0
# 444317   1553436     19.0     0         0         0         0
# 444318   1553448     64.0     0         0         0         1
#
#                                               meds_vector  \
# 0                                                     NaN
# 1       [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 444314  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 444315                                                NaN
# 444316  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 444317                                                NaN
# 444318                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 444314                                                NaN
# 444315                                                NaN
# 444316                                                NaN
# 444317  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444318                                                NaN
#
#                                            history_vector  SEX_F  SEX_M
# 0                                                     NaN      1      0
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0
# 2                                                     NaN      1      0
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0
# 4                                                     NaN      1      0
# ...                                                   ...    ...    ...
# 444314  [ 0.4257    -0.52978    0.37835   -0.28299   -...      0      1
# 444315                                                NaN      0      1
# 444316  [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0
# 444317                                                NaN      0      1
# 444318                                                NaN      0      1
#
# [444319 rows x 11 columns]

# %%
data['DIED'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
def label_risk (row):
    if row['DIED'] + row['L_THREAT'] + row['ER_VISIT'] + row['HOSPITAL'] > 1 :
        return 1
    else:
        return 0

# %%
data['risk'] = data.apply (lambda row: label_risk(row), axis=1)

# %%
data
# Out:
#         VAERS_ID  AGE_YRS  DIED  L_THREAT  ER_VISIT  HOSPITAL  \
# 0         916600     33.0     0         0         0         0
# 1         916601     73.0     0         0         0         0
# 2         916602     23.0     0         0         0         0
# 3         916603     58.0     0         0         0         0
# 4         916604     47.0     0         0         0         0
# ...          ...      ...   ...       ...       ...       ...
# 444314   1553408      NaN     0         0         0         0
# 444315   1553414      NaN     0         0         0         0
# 444316   1553416     81.0     0         0         0         0
# 444317   1553436     19.0     0         0         0         0
# 444318   1553448     64.0     0         0         0         1
#
#                                               meds_vector  \
# 0                                                     NaN
# 1       [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 444314  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 444315                                                NaN
# 444316  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 444317                                                NaN
# 444318                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 444314                                                NaN
# 444315                                                NaN
# 444316                                                NaN
# 444317  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444318                                                NaN
#
#                                            history_vector  SEX_F  SEX_M  risk
# 0                                                     NaN      1      0     0
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 2                                                     NaN      1      0     0
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 4                                                     NaN      1      0     0
# ...                                                   ...    ...    ...   ...
# 444314  [ 0.4257    -0.52978    0.37835   -0.28299   -...      0      1     0
# 444315                                                NaN      0      1     0
# 444316  [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 444317                                                NaN      0      1     0
# 444318                                                NaN      0      1     0
#
# [444319 rows x 12 columns]

# %%
data['risk'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.drop(['DIED','L_THREAT','ER_VISIT','HOSPITAL'],axis='columns', inplace=True)

# %%
data
# Out:
#         VAERS_ID  AGE_YRS                                        meds_vector  \
# 0         916600     33.0                                                NaN
# 1         916601     73.0  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2         916602     23.0                                                NaN
# 3         916603     58.0                                                NaN
# 4         916604     47.0                                                NaN
# ...          ...      ...                                                ...
# 444314   1553408      NaN  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 444315   1553414      NaN                                                NaN
# 444316   1553416     81.0  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 444317   1553436     19.0                                                NaN
# 444318   1553448     64.0                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 444314                                                NaN
# 444315                                                NaN
# 444316                                                NaN
# 444317  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 444318                                                NaN
#
#                                            history_vector  SEX_F  SEX_M  risk
# 0                                                     NaN      1      0     0
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 2                                                     NaN      1      0     0
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 4                                                     NaN      1      0     0
# ...                                                   ...    ...    ...   ...
# 444314  [ 0.4257    -0.52978    0.37835   -0.28299   -...      0      1     0
# 444315                                                NaN      0      1     0
# 444316  [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 444317                                                NaN      0      1     0
# 444318                                                NaN      0      1     0
#
# [444319 rows x 8 columns]

# %%
data2=pd.read_csv('2021VAERSVAX_clean3.csv')

# %%
data=data.merge(data2, on='VAERS_ID',how='inner')

# %%
data
# Out:
#         VAERS_ID  AGE_YRS                                        meds_vector  \
# 0         916600     33.0                                                NaN
# 1         916601     73.0  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2         916602     23.0                                                NaN
# 3         916603     58.0                                                NaN
# 4         916604     47.0                                                NaN
# ...          ...      ...                                                ...
# 459492   1553408      NaN  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 459493   1553414      NaN                                                NaN
# 459494   1553416     81.0  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 459495   1553436     19.0                                                NaN
# 459496   1553448     64.0                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 459492                                                NaN
# 459493                                                NaN
# 459494                                                NaN
# 459495  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 459496                                                NaN
#
#                                            history_vector  SEX_F  SEX_M  risk  \
# 0                                                     NaN      1      0     0
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 2                                                     NaN      1      0     0
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 4                                                     NaN      1      0     0
# ...                                                   ...    ...    ...   ...
# 459492  [ 0.4257    -0.52978    0.37835   -0.28299   -...      0      1     0
# 459493                                                NaN      0      1     0
# 459494  [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 459495                                                NaN      0      1     0
# 459496                                                NaN      0      1     0
#
#        VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_SITE  \
# 0       COVID19          MODERNA  037K20A               1       LA
# 1       COVID19          MODERNA  025L20A               1       RA
# 2       COVID19  PFIZER\BIONTECH   EL1284               1       LA
# 3       COVID19          MODERNA      NaN             NaN      NaN
# 4       COVID19          MODERNA      NaN               1       LA
# ...         ...              ...      ...             ...      ...
# 459492  COVID19          MODERNA  052620A               1       RA
# 459493  COVID19          MODERNA  012M20A               1       RA
# 459494  COVID19          MODERNA  039K20A               1       RA
# 459495  COVID19  PFIZER\BIONTECH   EW0180               3       LA
# 459496  COVID19          JANSSEN      NaN             NaN      NaN
#
#                                    VAX_NAME
# 0               COVID19 (COVID19 (MODERNA))
# 1               COVID19 (COVID19 (MODERNA))
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))
# 3               COVID19 (COVID19 (MODERNA))
# 4               COVID19 (COVID19 (MODERNA))
# ...                                     ...
# 459492          COVID19 (COVID19 (MODERNA))
# 459493          COVID19 (COVID19 (MODERNA))
# 459494          COVID19 (COVID19 (MODERNA))
# 459495  COVID19 (COVID19 (PFIZER-BIONTECH))
# 459496          COVID19 (COVID19 (JANSSEN))
#
# [459497 rows x 14 columns]

# %%
data.drop(['VAX_TYPE','VAX_MANU','VAX_LOT','VAX_DOSE_SERIES','VAX_SITE'],axis='columns', inplace=True)

# %%
data
# Out:
#         VAERS_ID  AGE_YRS                                        meds_vector  \
# 0         916600     33.0                                                NaN
# 1         916601     73.0  [ 0.0253243   0.024884   -0.2335778   0.013858...
# 2         916602     23.0                                                NaN
# 3         916603     58.0                                                NaN
# 4         916604     47.0                                                NaN
# ...          ...      ...                                                ...
# 459492   1553408      NaN  [ 8.40699971e-02  3.45880002e-01  4.12244976e-...
# 459493   1553414      NaN                                                NaN
# 459494   1553416     81.0  [ 0.31707    0.41464    0.38131   -0.29494    ...
# 459495   1553436     19.0                                                NaN
# 459496   1553448     64.0                                                NaN
#
#                                          allergies_vector  \
# 0       [ 1.83718994e-01 -3.00236672e-01  3.40096653e-...
# 1       [-3.0221e-01  3.1568e-03 -1.4152e-01  2.5837e-...
# 2       [-0.30517   -0.41038    0.059648  -0.48996    ...
# 3       [-0.33855534 -0.17594332  0.25119236  0.024586...
# 4                                                     NaN
# ...                                                   ...
# 459492                                                NaN
# 459493                                                NaN
# 459494                                                NaN
# 459495  [ 0.4257    -0.52978    0.37835   -0.28299   -...
# 459496                                                NaN
#
#                                            history_vector  SEX_F  SEX_M  risk  \
# 0                                                     NaN      1      0     0
# 1       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 2                                                     NaN      1      0     0
# 3       [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 4                                                     NaN      1      0     0
# ...                                                   ...    ...    ...   ...
# 459492  [ 0.4257    -0.52978    0.37835   -0.28299   -...      0      1     0
# 459493                                                NaN      0      1     0
# 459494  [ 0.4257    -0.52978    0.37835   -0.28299   -...      1      0     0
# 459495                                                NaN      0      1     0
# 459496                                                NaN      0      1     0
#
#                                    VAX_NAME
# 0               COVID19 (COVID19 (MODERNA))
# 1               COVID19 (COVID19 (MODERNA))
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))
# 3               COVID19 (COVID19 (MODERNA))
# 4               COVID19 (COVID19 (MODERNA))
# ...                                     ...
# 459492          COVID19 (COVID19 (MODERNA))
# 459493          COVID19 (COVID19 (MODERNA))
# 459494          COVID19 (COVID19 (MODERNA))
# 459495  COVID19 (COVID19 (PFIZER-BIONTECH))
# 459496          COVID19 (COVID19 (JANSSEN))
#
# [459497 rows x 9 columns]

# %%
type(data['meds_vector'])
# Out:
# pandas.core.series.Series

# %%
# delete rows with nan values
newdata = data.dropna(axis=0, how='any')

# %%
newdata.shape
# Out:
# (104069, 9)

# %%
def tofloatlist(row):
    row_list=(((row)[3:-2]).split())
    return list(map(float,row_list))

# %%
import ast
def li(i):
    return ast.literal_eval(i)

# %%
# for i, row in data.iterrows():
#     if not row['meds_vector']:
#         data["meds_vector"][i]=tofloatlist(data["meds_vector"][i])
#     if not row['allergies_vector']:
#         data["allergies_vector"][i]=tofloatlist(data["allergies_vector"][i])
#     if not row['history_vector']:
#         data["history_vector"][i]=tofloatlist(data["history_vector"][i])

#     if row["meds_vector"] != "nan":
#         row["meds_vector"] = row["meds_vector"].apply(lambda x:li(x))

# %%
# for index, row in data.iterrows():
#     # check if the row is empty
#     if not row['allergies_vector']:
#         data.loc[index, "allergies_vector"] = li(data.loc[index, "allergies_vector"])
#     if not row['history_vector']:
#         data.loc[index, "history_vector"] = li(data.loc[index, "history_vector"])

# %%
for i,j in newdata["meds_vector"].iteritems():
    newdata["meds_vector"][i]=tofloatlist(newdata["meds_vector"][i])
# Out:
# C:\Users\santosh bishnoi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\santosh bishnoi\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for i,j in newdata["allergies_vector"].iteritems():
    newdata["allergies_vector"][i]=tofloatlist(newdata["allergies_vector"][i])
# Out:
# C:\Users\santosh bishnoi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i,j in newdata["history_vector"].iteritems():
    newdata["history_vector"][i]=tofloatlist(newdata["history_vector"][i])
# Out:
# C:\Users\santosh bishnoi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
newdata['allergies_vector']
# Out:
# 1         [0.00221, 0.0031568, -0.14152, 0.025837, 0.590...
# 7         [0.4257, -0.52978, 0.37835, -0.28299, -0.48079...
# 9         [0.00016614318, -0.23048915, 0.219673276, 0.06...
# 11        [0.186294, 0.096531, -0.08966247, -0.0180668, ...
# 12        [0.15393333, -0.37862667, 0.15700598, -0.09709...
#                                 ...
# 458043    [0.11675, -0.15802167, 0.10094001, -0.11322666...
# 458237    [0.26694, -0.38179, 0.37195, 0.39158, 0.58827,...
# 459439    [0.21177999, -0.09531848, 0.29061, 0.07263334,...
# 459475    [0.088742006, -0.0657332465, 0.268713981, -0.6...
# 459477    [0.091639821, -0.127368828, 0.0846981605, -0.2...
# Name: allergies_vector, Length: 104069, dtype: object

# %%
for index, row in newdata.iterrows():
    row["meds_vector"].append(row["AGE_YRS"])
    row["meds_vector"].append(row["SEX_F"])
    row["meds_vector"].append(row["SEX_M"])

# %%
for index, row in newdata.iterrows():
    row["allergies_vector"].append(row["AGE_YRS"])
    row["allergies_vector"].append(row["SEX_F"])
    row["allergies_vector"].append(row["SEX_M"])

    row["history_vector"].append(row["AGE_YRS"])
    row["history_vector"].append(row["SEX_F"])
    row["history_vector"].append(row["SEX_M"])

# %%
# for index, row in newdata.iterrows():
#     row["history_vector"].append(row["AGE_YRS"])
#     row["history_vector"].append(row["SEX_F"])
#     row["history_vector"].append(row["SEX_M"])

# %%
newdata.shape
# Out:
# (104069, 9)

# %%
only_risky=newdata[newdata["risk"]==1]

# %%
only_risky.shape
# Out:
# (2601, 9)

# %%
only_risky.to_csv("onlyrisky.csv")

# %%
def vector_avg(vec_list):
    vec_list=[np.array(i) for i in vec_list]
    return sum(vec_list)/len(vec_list)

# %%
from scipy import spatial
age=int(input("Enter Age"))

gender=int(input("Gender; 0 for male, 1 for female"))

-0.37006864, 0.11855308, 0.13152003, 0.19659846, -0.46482685, -0.025522238, 0.06650684, -0.11586672, 0.03197428, 0.05517224, -0.07812186, 0.0014836608, -0.12468508, 0.25229743, 0.18799645, 0.21846907, -0.15735865, -0.17049079, -0.08731848, 0.00659355, -0.15837452, -0.09335504, 0.019482022, -0.23304929, -0.15550041, 0.3838118, 0.06870092, 0.08055854, 0.07826076, -3.370643, 0.11981785, -0.19593774, -0.29847506, 0.14825878, 0.024335941, -0.017263336, -0.11070609, -0.08859644, -0.069170155, -0.18627559, -0.107450485, 0.10638401, 0.004957475, -0.21795662, -0.061861873, -0.012760878, 0.15929143, -0.15268089, -0.057644796, 0.007913079, 0.31892693, 0.07604047, 0.029000685, -0.059662268, 0.123322755, 0.11686171, -0.049657594, -0.025987498, 0.036571417, -0.11935442, -0.08542591, 0.02071436, 0.035999313, 0.023059987, 0.2421366, -0.15159406, -0.022166876, 0.15317646, -0.33146033, -0.027017012, 0.05383232, 0.17387962, -0.26545525, 0.13625519, -0.055333078, 0.2846078, -0.11891326, -0.003577811, 0.016855158, -0.062738754, 0.027325833, 0.039367292, 0.25633505, 0.37223792, -0.1146647, 0.045639385, 0.036743544, 0.07395653, 0.24851172, 0.2080753, 0.016608465, -0.07933307, 0.2605201, -0.055695143, -0.046811312, -0.0222397, -0.07160348, -0.14803497, 0.24806501, 0.053246323, -0.04436873, 0.039472345, -0.06902423, 0.47848344, -0.13215016, 43,0,1]

age_grp_df = only_risky.loc[(only_risky['AGE_YRS'] >= age-20) & (only_risky['AGE_YRS'] <= age+20)]

age_and_gender_df=age_grp_df[age_grp_df["SEX_F"]==gender]

# vec_list=[]

vaccine_list=[ "COVID19 (COVID19 (PFIZER-BIONTECH))","COVID19 (COVID19 (MODERNA))"]

for vaccine in vaccine_list:
    print(vaccine)
    vec_list_meds=[]
    vec_list_allergies=[]
    vec_list_history=[]

    vacdf=age_and_gender_df[age_and_gender_df['VAX_NAME']==vaccine]
    # print(vacdf)


    for i in vacdf["meds_vector"]:
        # print("lennnn",len(i))
        if len(i)==303:
            vec_list_meds.append(i)
        
    for i in vacdf["allergies_vector"]:
        if len(i)==303:
            vec_list_allergies.append(i)
        
    for i in vacdf["history_vector"]:
        if len(i)==303:
            vec_list_history.append(i)



# print(len(vec_list))
# print(vec_list)

    avg_vector_meds=vector_avg(vec_list_meds)
    avg_vector_allergies=vector_avg(vec_list_allergies)
    avg_vector_history=vector_avg(vec_list_history)

    
    result_meds=spatial.distance.cosine(avg_vector_meds,user_med_vector)
    result_allergies=spatial.distance.cosine(avg_vector_allergies,user_allergy_vector)
    result_history=spatial.distance.cosine(avg_vector_history,user_history_vector)
    
    print("Vaccine name:", vaccine)

    print("Risk Percentage :",max(result_meds,result_allergies, result_history)*100)
# Out:
# COVID19 (COVID19 (PFIZER-BIONTECH))
# Vaccine name: COVID19 (COVID19 (PFIZER-BIONTECH))
# Risk Percentage : 1.6255794060662687
# COVID19 (COVID19 (MODERNA))
# Vaccine name: COVID19 (COVID19 (MODERNA))
# Risk Percentage : 1.5683311325333738
