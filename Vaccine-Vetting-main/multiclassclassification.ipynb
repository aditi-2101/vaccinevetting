# %%
training_data=[['TX', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 73.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 23.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NV', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 50.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 33.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 71.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 18.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 71.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 28.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 65.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 22.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 61.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['ME', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ME', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 27.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 22.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 49.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 41.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 58.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ID', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 42.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 49.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MN', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TN', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ME', 61.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 59.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 41.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NE', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 20.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VA', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 61.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['DE', 39.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 22.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 52.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 36.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 56.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 69.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 37.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 20.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 59.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NV', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 70.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 41.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 51.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 57.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 69.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 23.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 39.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NE', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['RI', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 48.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 30.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['ME', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 62.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 27.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 68.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 45.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 58.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MS', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MS', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 52.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 45.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 56.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 54.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AR', 30.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ME', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AK', 54.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 48.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 55.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['RI', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 88.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 67.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['HI', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 42.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MN', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 54.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 51.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 55.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 43.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 42.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 52.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 57.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 55.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 46.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NV', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 78.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MT', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MD', 55.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 42.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 69.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 61.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 65.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NE', 29.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['RI', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MD', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PR', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 58.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 72.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KY', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 36.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 27.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PR', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 43.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 62.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 34.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 86.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['ND', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 60.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VA', 69.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 27.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MD', 43.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 71.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['SC', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 54.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 49.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NE', 40.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 37.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 73.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 35.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 23.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VT', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 61.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 48.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 66.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 93.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 50.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VT', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 28.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 22.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 46.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 35.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 47.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 27.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 41.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 64.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 62.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 33.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 45.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NV', 80.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 49.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 60.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 36.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 88.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 51.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 88.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 26.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TN', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 66.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['DC', 27.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 59.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 45.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 60.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 44.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 36.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ID', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MD', 40.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 23.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 25.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 35.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 51.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VA', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['UT', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KY', 58.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['SD', 65.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 58.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 82.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 51.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 61.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 43.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 38.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 19.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 68.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 43.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['HI', 58.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 65.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 19.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 59.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PR', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KY', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 53.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 32.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['UT', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TN', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 28.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['UT', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 58.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 48.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 60.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 42.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 37.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 27.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 66.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 74.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 59.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 38.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OK', 45.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 27.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 51.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MT', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 70.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OK', 62.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 59.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OK', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['UT', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 38.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 48.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 72.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 24.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 82.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['KY', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MS', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 35.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['HI', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AZ', 46.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['SD', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MD', 50.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AK', 23.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 20.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 32.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 65.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 56.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 59.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OK', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 54.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['HI', 21.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['AZ', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['RI', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 55.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 55.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['ME', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 68.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 58.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AL', 64.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MO', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 50.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 74.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 48.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 23.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AR', 61.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 65.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 46.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 38.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['SC', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ND', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 78.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 64.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 37.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['RI', 57.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 82.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NE', 25.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 63.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 26.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 49.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['ME', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 39.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 43.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 70.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 48.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 45.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OR', 92.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 25.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 53.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 76.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 62.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 68.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 22.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 80.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 83.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 72.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 54.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 36.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 27.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 97.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 84.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['SC', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AR', 63.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 87.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 77.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 46.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 82.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 93.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 79.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 92.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 85.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 85.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OK', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 85.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 83.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 21.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 76.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 87.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 83.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 80.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 41.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 68.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 75.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 82.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 64.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 90.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 88.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WY', 20.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 92.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NE', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 90.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 95.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 21.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 84.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 65.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 36.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 82.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 98.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 91.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 80.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 60.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 20.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 19.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 25.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 87.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 80.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 62.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WV', 83.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NJ', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 54.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 80.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 87.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 81.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 65.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 36.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 61.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 32.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MT', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 73.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 23.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 61.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AR', 36.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['UT', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 57.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['ME', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 24.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 27.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 68.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MN', 19.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 43.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 65.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 59.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WV', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 59.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 57.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 75.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 42.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 32.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 50.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 33.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 58.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 58.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 32.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 41.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MT', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['SC', 50.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 57.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 45.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 50.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 64.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 50.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 21.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 58.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 22.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 22.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PA', 37.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 26.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 48.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['SD', 77.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 63.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 28.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CO', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 67.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 38.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 56.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 23.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 39.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 29.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 35.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MT', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['FL', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 25.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 45.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MS', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NC', 61.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 22.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 34.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NM', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 79.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ME', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 55.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 83.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OK', 26.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 20.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 25.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AR', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 46.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 68.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['VA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 26.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 45.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 27.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 66.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 68.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CT', 59.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 41.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 51.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 55.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 62.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 40.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 49.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 51.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 37.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IA', 69.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 51.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 33.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 58.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 46.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CT', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MD', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 41.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 43.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 51.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IN', 25.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 35.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OR', 52.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 26.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 29.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 49.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 33.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 79.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 52.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['RI', 31.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TN', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 25.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AL', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['MI', 49.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 50.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['KS', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 39.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['FL', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 48.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 44.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['HI', 56.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 32.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['HI', 47.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AK', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IN', 42.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 58.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 38.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['PA', 60.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 22.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['KY', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 57.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AK', 60.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 20.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 39.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CA', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['TX', 39.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['AL', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['LA', 39.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WI', 22.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NY', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 41.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 46.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 24.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 37.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 28.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['SD', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 74.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 46.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 25.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 24.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 26.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 57.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MO', 59.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['SC', 52.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['HI', 54.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TN', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['WA', 43.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['GA', 51.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['VA', 26.0, 'M', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NC', 40.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['CA', 44.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['OH', 29.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 32.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['PR', 25.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['MA', 33.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 27.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['UT', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MI', 30.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['CO', 58.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NY', 68.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['IL', 34.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['MA', 36.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IA', 50.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['WI', 32.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['GA', 22.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['ME', 60.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['AL', 47.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['WA', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 68.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['OH', 66.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 26.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 34.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['AZ', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 64.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 36.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 70.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OK', 43.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['WA', 33.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 60.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 48.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 66.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 70.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 65.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 46.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 27.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['WI', 53.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 84.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['KY', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['ME', 67.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['KY', 35.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 66.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MS', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 25.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 68.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 25.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 62.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 49.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 40.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 62.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 41.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 17.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 53.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['UT', 42.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['ME', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OK', 23.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 27.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 59.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['AZ', 24.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NV', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 69.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 65.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 26.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 45.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 50.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MI', 73.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OK', 19.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MS', 58.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 37.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 60.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 59.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 28.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 36.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['UT', 37.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 66.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 37.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 70.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OR', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['UT', 67.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 36.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['UT', 59.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['WA', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MS', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 21.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 29.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 66.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 23.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 23.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NV', 51.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 26.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['WA', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 51.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 71.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 44.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 58.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OR', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 42.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 67.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 61.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 25.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 53.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 77.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 52.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 33.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 66.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 37.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 65.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 72.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 19.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 46.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 38.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 40.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 21.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 25.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 64.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 52.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 67.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OR', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 52.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['WA', 41.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 71.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 57.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 40.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 53.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['PA', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 36.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 62.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 46.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 49.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 47.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 59.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 28.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 59.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['SC', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 38.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 62.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 65.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 55.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VT', 20.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 68.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 33.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 73.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 54.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 19.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 55.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NV', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NH', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 27.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 51.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 41.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 68.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 28.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['PA', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 47.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 43.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 60.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 42.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 70.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 44.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 25.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 38.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 28.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 33.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 41.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 72.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 25.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['ME', 72.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 51.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NH', 71.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['PA', 54.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 55.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MS', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 70.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 30.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['PA', 76.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['GA', 42.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['GA', 25.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 54.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 49.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 48.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 52.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 20.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 67.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 80.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 70.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 64.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 72.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['UT', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 29.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 19.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IA', 42.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 38.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 43.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['AZ', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 40.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 47.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 48.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 55.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 70.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 22.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 50.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 36.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 24.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 36.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['SC', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 70.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['OK', 41.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 40.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 34.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 40.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 58.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 18.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 20.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 70.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 54.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 54.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 31.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 39.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 20.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NE', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['PA', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 30.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 36.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 56.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 32.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 58.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 30.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 40.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 22.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['MO', 26.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 64.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 63.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['SC', 40.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 44.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 36.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 23.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['SD', 58.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 55.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 35.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 46.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 28.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MD', 59.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['NC', 39.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 26.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 47.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 48.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 64.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 40.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 37.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 55.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 29.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DE', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 49.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 45.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 69.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 53.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MA', 67.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['IN', 57.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 65.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['MN', 65.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 51.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 51.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['DC', 27.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CT', 56.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 38.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['LA', 62.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NM', 73.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 63.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['TX', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['KY', 64.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['IL', 21.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['OH', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 66.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 34.0, 'M', 'COVID19 (COVID19 (JANSSEN))'],
 ['CO', 61.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['FL', 32.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['VA', 55.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NY', 60.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['NJ', 42.0, 'F', 'COVID19 (COVID19 (JANSSEN))'],
 ['CA', 28.0, 'M', 'COVID19 (COVID19 (JANSSEN))']
 ]

# %%
header = ["state", "age", "sex","vax"]

# %%
#unique values in the column
def unique_vals(rows, col):
    return set([row[col] for row in rows])

# %%
#Counts the number of each unique value a dataset.
def class_counts(rows):
    counts = {}  
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
#returns true if value is numeric
def is_numeric(value):
    return isinstance(value, int) or isinstance(value, float)

# %%
#condition based on which dataset is partitoned
class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

# %%
#partition the dataset based on the question asked
def partition(rows, question):
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#calculate gini impurity
def gini(rows):
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
#calculate info gain
def info_gain(left, right, current_uncertainty):
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
#Find the best value for dividing the data by iterating over every feature and calculating the information gain.
def find_best_split(rows):
    
    best_gain = 0  
    best_question = None  
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1 

    for col in range(n_features):  

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value
            question = Question(col, val)
            true_rows, false_rows = partition(rows, question)

            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)
           
            if gain > best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

# %%
#Leaf node
#self.predictions is a dictionary with the count of each output in that leaf
class Leaf:
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
#Decision node
class Decision_Node:
       def __init__(self,question,true_branch,false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
#depending on gain value, return question that produces highest gain or leaf node
def build_tree(rows):
    
    gain, question = find_best_split(rows)
    
    #if gain is 0, the node is a leaf node
    if gain == 0:
        return Leaf(rows)
    
    true_rows, false_rows = partition(rows, question)
    
    #recursively build the decision tree 
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)
    
    return Decision_Node(question, true_branch, false_branch)

# %%
my_tree = build_tree(training_data)

# %%
def classify(row, node):
    # returns a dict which has the count of each unique value at the leaf node
    if isinstance(node, Leaf):
        return node.predictions
        #print("node predictions",node.predictions)

    #decide whether to take true branch or false branch
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
def print_leaf(counts):
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = "The risk percentage is "+str(100-int(counts[lbl] / total * 100)) + "%"
    #print("count",counts,"total",total)
    return probs

# %%
'''
testing_data = [

 ['WA', 30.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['VT', 68.0, 'F', 'COVID19 (COVID19 (PFIZER-BIONTECH))'],
 ['NJ', 63.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['IL', 62.0, 'M', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['NH', 31.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 50.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['ID', 53.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
 ['TX', 45.0, 'F', 'COVID19 (COVID19 (MODERNA))'],
    
]
'''
testing_data = [

 ['WA', 30.0, 'F'],
 ['VT', 68.0, 'F'],
 ['NJ', 63.0, 'F'],
 ['IL', 62.0, 'M'],
 ['NH', 45.0, 'F'],
 ['NH', 31.0, 'F'],
 ['TX', 50.0, 'F'],
 ['ID', 53.0, 'F'],
 ['TX', 45.0, 'F'],
    
]

# %%
for row in testing_data:
    print (". Predicted: %s \n" %
           ( print_leaf(classify(row, my_tree))))
# Out:
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (PFIZER-BIONTECH))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (JANSSEN))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 0%'}
#
# . Predicted: {'COVID19 (COVID19 (MODERNA))': 'The risk percentage is 67%', 'COVID19 (COVID19 (JANSSEN))': 'The risk percentage is 34%'}
